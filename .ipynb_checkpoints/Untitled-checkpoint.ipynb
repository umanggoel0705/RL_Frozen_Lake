# %%
# !pip install pygame
# Out:
# Collecting pygame
#   Using cached pygame-2.6.1-cp312-cp312-win_amd64.whl.metadata (13 kB)
# Using cached pygame-2.6.1-cp312-cp312-win_amd64.whl (10.6 MB)
# Installing collected packages: pygame
# Successfully installed pygame-2.6.1

# %%
import os
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %%
import numpy as np
if not hasattr(np, 'bool8'):
    np.bool8 = np.bool_

# %%
watch_env = gym.make('FrozenLake-v1', render_mode='human')

# %%
watch_env.action_space
# Out:
# Discrete(4)

# %%
watch_env.observation_space
# Out:
# Discrete(16)

# %%
episodes = 5
for episode in range(episodes):
    state, _ = watch_env.reset()
    done = False
    truncated = False
    score = 0

    while not done and not truncated:
        action = watch_env.action_space.sample()
        n_state, reward, done, truncated, info = watch_env.step(action)
        score += reward
    print(f"Episode: {episode+1} Score: {score}")
watch_env.close()
# Out:
# Episode: 1 Score: 0.0
# Episode: 2 Score: 0.0
# Episode: 3 Score: 0.0
# Episode: 4 Score: 0.0
# Episode: 5 Score: 0.0

# %%
train_env = gym.make('FrozenLake-v1')
train_env = DummyVecEnv([lambda : train_env])
model = PPO('MlpPolicy', train_env, verbose=1)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=1000000)
# Out:
# -----------------------------
# | time/              |      |
# |    fps             | 2115 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1479        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.018039888 |
# |    clip_fraction        | 0.0773      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | -3.49       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0237     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00998    |
# |    value_loss           | 0.0147      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1363        |
# |    iterations           | 3           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.007803429 |
# |    clip_fraction        | 0.0451      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.111       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00451     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0101     |
# |    value_loss           | 0.0208      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1300         |
# |    iterations           | 4            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0108683705 |
# |    clip_fraction        | 0.0872       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | -0.00788     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0106       |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00952     |
# |    value_loss           | 0.00778      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1268        |
# |    iterations           | 5           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.011465091 |
# |    clip_fraction        | 0.0795      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.135       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0278     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0105     |
# |    value_loss           | 0.012       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1228        |
# |    iterations           | 6           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.017503835 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.0525      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0204     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00944    |
# |    value_loss           | 0.0173      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1064        |
# |    iterations           | 7           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.013785096 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0.175       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0236     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0136     |
# |    value_loss           | 0.0106      |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1010       |
# |    iterations           | 8          |
# |    time_elapsed         | 16         |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.01040979 |
# |    clip_fraction        | 0.109      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.18      |
# |    explained_variance   | 0.134      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0133     |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.0101    |
# |    value_loss           | 0.0271     |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 983         |
# |    iterations           | 9           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.013739688 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | 0.0539      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00792    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0112     |
# |    value_loss           | 0.0257      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 999         |
# |    iterations           | 10          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.009460889 |
# |    clip_fraction        | 0.054       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.159       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00505    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00605    |
# |    value_loss           | 0.0184      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1015        |
# |    iterations           | 11          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.013611089 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.109       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00115     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00835    |
# |    value_loss           | 0.0327      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1026        |
# |    iterations           | 12          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.009641126 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.992      |
# |    explained_variance   | 0.132       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0267     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0106     |
# |    value_loss           | 0.027       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1037       |
# |    iterations           | 13         |
# |    time_elapsed         | 25         |
# |    total_timesteps      | 26624      |
# | train/                  |            |
# |    approx_kl            | 0.00995228 |
# |    clip_fraction        | 0.102      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.932     |
# |    explained_variance   | 0.189      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0094     |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.00767   |
# |    value_loss           | 0.0338     |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1047        |
# |    iterations           | 14          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.008455868 |
# |    clip_fraction        | 0.0826      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.866      |
# |    explained_variance   | 0.21        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0249      |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00937    |
# |    value_loss           | 0.0503      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1055        |
# |    iterations           | 15          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.009823533 |
# |    clip_fraction        | 0.0525      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.804      |
# |    explained_variance   | 0.0496      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.018       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00757    |
# |    value_loss           | 0.0515      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1064         |
# |    iterations           | 16           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0061103017 |
# |    clip_fraction        | 0.0828       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.783       |
# |    explained_variance   | 0.0948       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00034      |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.0103      |
# |    value_loss           | 0.0435       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1071        |
# |    iterations           | 17          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.005690106 |
# |    clip_fraction        | 0.0768      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.744      |
# |    explained_variance   | 0.127       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0259      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00887    |
# |    value_loss           | 0.0568      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1077         |
# |    iterations           | 18           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0065550697 |
# |    clip_fraction        | 0.0856       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.689       |
# |    explained_variance   | 0.116        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00971      |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00781     |
# |    value_loss           | 0.0327       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1080         |
# |    iterations           | 19           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0072300117 |
# |    clip_fraction        | 0.104        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.649       |
# |    explained_variance   | 0.163        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0285       |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.0125      |
# |    value_loss           | 0.058        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1085        |
# |    iterations           | 20          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.004950636 |
# |    clip_fraction        | 0.0456      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.646      |
# |    explained_variance   | 0.144       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0256      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00443    |
# |    value_loss           | 0.0548      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1083         |
# |    iterations           | 21           |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0054501924 |
# |    clip_fraction        | 0.0469       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.618       |
# |    explained_variance   | 0.0997       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0314       |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00682     |
# |    value_loss           | 0.0512       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1054        |
# |    iterations           | 22          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.005259472 |
# |    clip_fraction        | 0.05        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.544      |
# |    explained_variance   | 0.161       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0416      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0049     |
# |    value_loss           | 0.0607      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1053        |
# |    iterations           | 23          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.004853587 |
# |    clip_fraction        | 0.0472      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.496      |
# |    explained_variance   | 0.178       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0348      |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00583    |
# |    value_loss           | 0.0631      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1034        |
# |    iterations           | 24          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.004298934 |
# |    clip_fraction        | 0.0628      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.446      |
# |    explained_variance   | 0.114       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0242      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00808    |
# |    value_loss           | 0.0654      |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1016       |
# |    iterations           | 25         |
# |    time_elapsed         | 50         |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.00305118 |
# |    clip_fraction        | 0.0453     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.411     |
# |    explained_variance   | 0.105      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0264     |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.00603   |
# |    value_loss           | 0.0601     |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1018         |
# |    iterations           | 26           |
# |    time_elapsed         | 52           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0023089042 |
# |    clip_fraction        | 0.0377       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.359       |
# |    explained_variance   | 0.173        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0224       |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.005       |
# |    value_loss           | 0.0455       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1015         |
# |    iterations           | 27           |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0019514475 |
# |    clip_fraction        | 0.0273       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.329       |
# |    explained_variance   | 0.0582       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0308       |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.0037      |
# |    value_loss           | 0.0568       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1015         |
# |    iterations           | 28           |
# |    time_elapsed         | 56           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0022609055 |
# |    clip_fraction        | 0.0418       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.28        |
# |    explained_variance   | 0.107        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0319       |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.0043      |
# |    value_loss           | 0.0575       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1015        |
# |    iterations           | 29          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.001766827 |
# |    clip_fraction        | 0.0238      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.257      |
# |    explained_variance   | 0.111       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0206      |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00365    |
# |    value_loss           | 0.0552      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1016         |
# |    iterations           | 30           |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0025960775 |
# |    clip_fraction        | 0.0189       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.246       |
# |    explained_variance   | 0.0253       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0245       |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00253     |
# |    value_loss           | 0.0605       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1017         |
# |    iterations           | 31           |
# |    time_elapsed         | 62           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0016882753 |
# |    clip_fraction        | 0.0171       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.216       |
# |    explained_variance   | 0.128        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.023        |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00252     |
# |    value_loss           | 0.0506       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1020         |
# |    iterations           | 32           |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0021225042 |
# |    clip_fraction        | 0.0159       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.211       |
# |    explained_variance   | 0.0768       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0214       |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00392     |
# |    value_loss           | 0.0464       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1020         |
# |    iterations           | 33           |
# |    time_elapsed         | 66           |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0011125032 |
# |    clip_fraction        | 0.0177       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.187       |
# |    explained_variance   | 0.0658       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0282       |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00307     |
# |    value_loss           | 0.0547       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1017         |
# |    iterations           | 34           |
# |    time_elapsed         | 68           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0020035652 |
# |    clip_fraction        | 0.0204       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.177       |
# |    explained_variance   | 0.148        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0115       |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00391     |
# |    value_loss           | 0.0508       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1019         |
# |    iterations           | 35           |
# |    time_elapsed         | 70           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0009249103 |
# |    clip_fraction        | 0.0173       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.147       |
# |    explained_variance   | 0.115        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00702      |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00389     |
# |    value_loss           | 0.0506       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1021        |
# |    iterations           | 36          |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.001957618 |
# |    clip_fraction        | 0.018       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.157      |
# |    explained_variance   | 0.132       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0238      |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00263    |
# |    value_loss           | 0.0514      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1021         |
# |    iterations           | 37           |
# |    time_elapsed         | 74           |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0008791049 |
# |    clip_fraction        | 0.0127       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.132       |
# |    explained_variance   | 0.103        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0268       |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00217     |
# |    value_loss           | 0.0487       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1019         |
# |    iterations           | 38           |
# |    time_elapsed         | 76           |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0008606897 |
# |    clip_fraction        | 0.0108       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.133       |
# |    explained_variance   | 0.179        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0162       |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00131     |
# |    value_loss           | 0.0418       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1018         |
# |    iterations           | 39           |
# |    time_elapsed         | 78           |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0010059347 |
# |    clip_fraction        | 0.0128       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.145       |
# |    explained_variance   | 0.124        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0258       |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00207     |
# |    value_loss           | 0.0507       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1020        |
# |    iterations           | 40          |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.000929005 |
# |    clip_fraction        | 0.0109      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.15       |
# |    explained_variance   | 0.105       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.026       |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00151    |
# |    value_loss           | 0.0543      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1021         |
# |    iterations           | 41           |
# |    time_elapsed         | 82           |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0011577345 |
# |    clip_fraction        | 0.0192       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.141       |
# |    explained_variance   | 0.0964       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0271       |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00268     |
# |    value_loss           | 0.0531       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1021         |
# |    iterations           | 42           |
# |    time_elapsed         | 84           |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0015523906 |
# |    clip_fraction        | 0.0234       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.142       |
# |    explained_variance   | 0.182        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0293       |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00288     |
# |    value_loss           | 0.0529       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1022         |
# |    iterations           | 43           |
# |    time_elapsed         | 86           |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0014964882 |
# |    clip_fraction        | 0.0188       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.122       |
# |    explained_variance   | 0.111        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0378       |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00228     |
# |    value_loss           | 0.0524       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1022         |
# |    iterations           | 44           |
# |    time_elapsed         | 88           |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0010484912 |
# |    clip_fraction        | 0.0174       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.125       |
# |    explained_variance   | 0.126        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00954      |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00225     |
# |    value_loss           | 0.0412       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1023         |
# |    iterations           | 45           |
# |    time_elapsed         | 90           |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0015672785 |
# |    clip_fraction        | 0.0266       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.101       |
# |    explained_variance   | 0.0436       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0252       |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00495     |
# |    value_loss           | 0.0488       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1024        |
# |    iterations           | 46          |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.001358236 |
# |    clip_fraction        | 0.0113      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.103      |
# |    explained_variance   | 0.132       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0202      |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00224    |
# |    value_loss           | 0.0431      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1025         |
# |    iterations           | 47           |
# |    time_elapsed         | 93           |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0018150989 |
# |    clip_fraction        | 0.0172       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0937      |
# |    explained_variance   | 0.112        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0174       |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00246     |
# |    value_loss           | 0.0443       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1025         |
# |    iterations           | 48           |
# |    time_elapsed         | 95           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0006453644 |
# |    clip_fraction        | 0.00986      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0836      |
# |    explained_variance   | 0.119        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0177       |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00159     |
# |    value_loss           | 0.0486       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1026         |
# |    iterations           | 49           |
# |    time_elapsed         | 97           |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0013679316 |
# |    clip_fraction        | 0.0154       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0781      |
# |    explained_variance   | 0.0727       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0189       |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00238     |
# |    value_loss           | 0.0453       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1027         |
# |    iterations           | 50           |
# |    time_elapsed         | 99           |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0008065713 |
# |    clip_fraction        | 0.0109       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0697      |
# |    explained_variance   | 0.162        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0153       |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00127     |
# |    value_loss           | 0.0358       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1026        |
# |    iterations           | 51          |
# |    time_elapsed         | 101         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.001142073 |
# |    clip_fraction        | 0.0105      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0631     |
# |    explained_variance   | 0.106       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0222      |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00157    |
# |    value_loss           | 0.0417      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1027         |
# |    iterations           | 52           |
# |    time_elapsed         | 103          |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0010069362 |
# |    clip_fraction        | 0.0121       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0659      |
# |    explained_variance   | 0.122        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0241       |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.00171     |
# |    value_loss           | 0.0415       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1027         |
# |    iterations           | 53           |
# |    time_elapsed         | 105          |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0009660633 |
# |    clip_fraction        | 0.0169       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0899      |
# |    explained_variance   | 0.126        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0299       |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.000939    |
# |    value_loss           | 0.0496       |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1028          |
# |    iterations           | 54            |
# |    time_elapsed         | 107           |
# |    total_timesteps      | 110592        |
# | train/                  |               |
# |    approx_kl            | 0.00081992743 |
# |    clip_fraction        | 0.00889       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0694       |
# |    explained_variance   | 0.129         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0227        |
# |    n_updates            | 530           |
# |    policy_gradient_loss | -0.00178      |
# |    value_loss           | 0.044         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1028         |
# |    iterations           | 55           |
# |    time_elapsed         | 109          |
# |    total_timesteps      | 112640       |
# | train/                  |              |
# |    approx_kl            | 0.0023355447 |
# |    clip_fraction        | 0.0176       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0805      |
# |    explained_variance   | 0.108        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0141       |
# |    n_updates            | 540          |
# |    policy_gradient_loss | -0.00187     |
# |    value_loss           | 0.0412       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1030         |
# |    iterations           | 56           |
# |    time_elapsed         | 111          |
# |    total_timesteps      | 114688       |
# | train/                  |              |
# |    approx_kl            | 0.0015102164 |
# |    clip_fraction        | 0.0132       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.08        |
# |    explained_variance   | 0.113        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0283       |
# |    n_updates            | 550          |
# |    policy_gradient_loss | -0.00113     |
# |    value_loss           | 0.0445       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1029         |
# |    iterations           | 57           |
# |    time_elapsed         | 113          |
# |    total_timesteps      | 116736       |
# | train/                  |              |
# |    approx_kl            | 0.0014286388 |
# |    clip_fraction        | 0.0194       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0908      |
# |    explained_variance   | 0.136        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0232       |
# |    n_updates            | 560          |
# |    policy_gradient_loss | -0.00279     |
# |    value_loss           | 0.0528       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1018         |
# |    iterations           | 58           |
# |    time_elapsed         | 116          |
# |    total_timesteps      | 118784       |
# | train/                  |              |
# |    approx_kl            | 0.0016465848 |
# |    clip_fraction        | 0.0227       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0669      |
# |    explained_variance   | 0.0991       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0199       |
# |    n_updates            | 570          |
# |    policy_gradient_loss | -0.00363     |
# |    value_loss           | 0.051        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1015         |
# |    iterations           | 59           |
# |    time_elapsed         | 119          |
# |    total_timesteps      | 120832       |
# | train/                  |              |
# |    approx_kl            | 0.0009781932 |
# |    clip_fraction        | 0.0136       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0723      |
# |    explained_variance   | 0.12         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0287       |
# |    n_updates            | 580          |
# |    policy_gradient_loss | -0.00167     |
# |    value_loss           | 0.0431       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1014         |
# |    iterations           | 60           |
# |    time_elapsed         | 121          |
# |    total_timesteps      | 122880       |
# | train/                  |              |
# |    approx_kl            | 0.0007117069 |
# |    clip_fraction        | 0.00586      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.065       |
# |    explained_variance   | 0.0895       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0287       |
# |    n_updates            | 590          |
# |    policy_gradient_loss | -0.000619    |
# |    value_loss           | 0.0397       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1012         |
# |    iterations           | 61           |
# |    time_elapsed         | 123          |
# |    total_timesteps      | 124928       |
# | train/                  |              |
# |    approx_kl            | 0.0009799448 |
# |    clip_fraction        | 0.0153       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0759      |
# |    explained_variance   | 0.0875       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0221       |
# |    n_updates            | 600          |
# |    policy_gradient_loss | -0.00199     |
# |    value_loss           | 0.0477       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1013         |
# |    iterations           | 62           |
# |    time_elapsed         | 125          |
# |    total_timesteps      | 126976       |
# | train/                  |              |
# |    approx_kl            | 0.0008965186 |
# |    clip_fraction        | 0.00571      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.081       |
# |    explained_variance   | 0.0843       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0298       |
# |    n_updates            | 610          |
# |    policy_gradient_loss | -0.000715    |
# |    value_loss           | 0.0436       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1014        |
# |    iterations           | 63          |
# |    time_elapsed         | 127         |
# |    total_timesteps      | 129024      |
# | train/                  |             |
# |    approx_kl            | 0.002815704 |
# |    clip_fraction        | 0.0193      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0729     |
# |    explained_variance   | 0.117       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0119      |
# |    n_updates            | 620         |
# |    policy_gradient_loss | -0.00316    |
# |    value_loss           | 0.0431      |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1016          |
# |    iterations           | 64            |
# |    time_elapsed         | 129           |
# |    total_timesteps      | 131072        |
# ...
# |    clip_fraction        | 0.0123      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0242     |
# |    explained_variance   | 0.271       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0176      |
# |    n_updates            | 4680        |
# |    policy_gradient_loss | -0.00173    |
# |    value_loss           | 0.0309      |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1077          |
# |    iterations           | 470           |
# |    time_elapsed         | 893           |
# |    total_timesteps      | 962560        |
# | train/                  |               |
# |    approx_kl            | 0.00018030775 |
# |    clip_fraction        | 0.00215       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0348       |
# |    explained_variance   | 0.186         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0127        |
# |    n_updates            | 4690          |
# |    policy_gradient_loss | 0.000118      |
# |    value_loss           | 0.045         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1077         |
# |    iterations           | 471          |
# |    time_elapsed         | 894          |
# |    total_timesteps      | 964608       |
# | train/                  |              |
# |    approx_kl            | 0.0004883465 |
# |    clip_fraction        | 0.00669      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0284      |
# |    explained_variance   | 0.199        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00103      |
# |    n_updates            | 4700         |
# |    policy_gradient_loss | -0.0011      |
# |    value_loss           | 0.0348       |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1078          |
# |    iterations           | 472           |
# |    time_elapsed         | 896           |
# |    total_timesteps      | 966656        |
# | train/                  |               |
# |    approx_kl            | 0.00086068036 |
# |    clip_fraction        | 0.0104        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0282       |
# |    explained_variance   | 0.208         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00626       |
# |    n_updates            | 4710          |
# |    policy_gradient_loss | -0.002        |
# |    value_loss           | 0.0324        |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1078         |
# |    iterations           | 473          |
# |    time_elapsed         | 898          |
# |    total_timesteps      | 968704       |
# | train/                  |              |
# |    approx_kl            | 0.0017380142 |
# |    clip_fraction        | 0.0242       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0362      |
# |    explained_variance   | 0.178        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0237       |
# |    n_updates            | 4720         |
# |    policy_gradient_loss | -0.00313     |
# |    value_loss           | 0.0457       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1078        |
# |    iterations           | 474         |
# |    time_elapsed         | 899         |
# |    total_timesteps      | 970752      |
# | train/                  |             |
# |    approx_kl            | 0.005978387 |
# |    clip_fraction        | 0.0357      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0727     |
# |    explained_variance   | 0.0585      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00394     |
# |    n_updates            | 4730        |
# |    policy_gradient_loss | -0.00465    |
# |    value_loss           | 0.0434      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1078         |
# |    iterations           | 475          |
# |    time_elapsed         | 901          |
# |    total_timesteps      | 972800       |
# | train/                  |              |
# |    approx_kl            | 0.0019300595 |
# |    clip_fraction        | 0.016        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0798      |
# |    explained_variance   | 0.0784       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0306       |
# |    n_updates            | 4740         |
# |    policy_gradient_loss | -0.000676    |
# |    value_loss           | 0.0539       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1079         |
# |    iterations           | 476          |
# |    time_elapsed         | 903          |
# |    total_timesteps      | 974848       |
# | train/                  |              |
# |    approx_kl            | 0.0036384664 |
# |    clip_fraction        | 0.0179       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0699      |
# |    explained_variance   | 0.0975       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0195       |
# |    n_updates            | 4750         |
# |    policy_gradient_loss | -0.00218     |
# |    value_loss           | 0.0454       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1079         |
# |    iterations           | 477          |
# |    time_elapsed         | 905          |
# |    total_timesteps      | 976896       |
# | train/                  |              |
# |    approx_kl            | 0.0042585665 |
# |    clip_fraction        | 0.0115       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0627      |
# |    explained_variance   | 0.205        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0146       |
# |    n_updates            | 4760         |
# |    policy_gradient_loss | -0.00235     |
# |    value_loss           | 0.0445       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1079         |
# |    iterations           | 478          |
# |    time_elapsed         | 906          |
# |    total_timesteps      | 978944       |
# | train/                  |              |
# |    approx_kl            | 0.0010317849 |
# |    clip_fraction        | 0.0108       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0474      |
# |    explained_variance   | 0.145        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.019        |
# |    n_updates            | 4770         |
# |    policy_gradient_loss | -0.00324     |
# |    value_loss           | 0.0457       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1079         |
# |    iterations           | 479          |
# |    time_elapsed         | 908          |
# |    total_timesteps      | 980992       |
# | train/                  |              |
# |    approx_kl            | 0.0013743928 |
# |    clip_fraction        | 0.00889      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0416      |
# |    explained_variance   | 0.2          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0202       |
# |    n_updates            | 4780         |
# |    policy_gradient_loss | -0.00224     |
# |    value_loss           | 0.036        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1079          |
# |    iterations           | 480           |
# |    time_elapsed         | 910           |
# |    total_timesteps      | 983040        |
# | train/                  |               |
# |    approx_kl            | 0.00021229143 |
# |    clip_fraction        | 0.00303       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0364       |
# |    explained_variance   | 0.177         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0208        |
# |    n_updates            | 4790          |
# |    policy_gradient_loss | -0.000255     |
# |    value_loss           | 0.0438        |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1080          |
# |    iterations           | 481           |
# |    time_elapsed         | 911           |
# |    total_timesteps      | 985088        |
# | train/                  |               |
# |    approx_kl            | 0.00037606136 |
# |    clip_fraction        | 0.00605       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0344       |
# |    explained_variance   | 0.185         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0274        |
# |    n_updates            | 4800          |
# |    policy_gradient_loss | -0.00135      |
# |    value_loss           | 0.0406        |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1080         |
# |    iterations           | 482          |
# |    time_elapsed         | 913          |
# |    total_timesteps      | 987136       |
# | train/                  |              |
# |    approx_kl            | 0.0011417147 |
# |    clip_fraction        | 0.00405      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0241      |
# |    explained_variance   | 0.21         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.017        |
# |    n_updates            | 4810         |
# |    policy_gradient_loss | -0.0011      |
# |    value_loss           | 0.0348       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1080         |
# |    iterations           | 483          |
# |    time_elapsed         | 915          |
# |    total_timesteps      | 989184       |
# | train/                  |              |
# |    approx_kl            | 0.0019110492 |
# |    clip_fraction        | 0.00283      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0306      |
# |    explained_variance   | 0.105        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0127       |
# |    n_updates            | 4820         |
# |    policy_gradient_loss | -0.000959    |
# |    value_loss           | 0.0384       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1080         |
# |    iterations           | 484          |
# |    time_elapsed         | 917          |
# |    total_timesteps      | 991232       |
# | train/                  |              |
# |    approx_kl            | 0.0155323045 |
# |    clip_fraction        | 0.00742      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0303      |
# |    explained_variance   | 0.178        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0151       |
# |    n_updates            | 4830         |
# |    policy_gradient_loss | -0.00277     |
# |    value_loss           | 0.0409       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1080         |
# |    iterations           | 485          |
# |    time_elapsed         | 918          |
# |    total_timesteps      | 993280       |
# | train/                  |              |
# |    approx_kl            | 0.0012221418 |
# |    clip_fraction        | 0.00605      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.021       |
# |    explained_variance   | 0.116        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00235      |
# |    n_updates            | 4840         |
# |    policy_gradient_loss | -0.00128     |
# |    value_loss           | 0.0429       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1081         |
# |    iterations           | 486          |
# |    time_elapsed         | 920          |
# |    total_timesteps      | 995328       |
# | train/                  |              |
# |    approx_kl            | 0.0015032517 |
# |    clip_fraction        | 0.00942      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0336      |
# |    explained_variance   | 0.177        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0141       |
# |    n_updates            | 4850         |
# |    policy_gradient_loss | -0.0016      |
# |    value_loss           | 0.0396       |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1081          |
# |    iterations           | 487           |
# |    time_elapsed         | 922           |
# |    total_timesteps      | 997376        |
# | train/                  |               |
# |    approx_kl            | 0.00019007071 |
# |    clip_fraction        | 0.00937       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0258       |
# |    explained_variance   | 0.234         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0164        |
# |    n_updates            | 4860          |
# |    policy_gradient_loss | -0.000518     |
# |    value_loss           | 0.0358        |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1081        |
# |    iterations           | 488         |
# |    time_elapsed         | 924         |
# |    total_timesteps      | 999424      |
# | train/                  |             |
# |    approx_kl            | 0.000647964 |
# |    clip_fraction        | 0.00737     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0335     |
# |    explained_variance   | 0.126       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0176      |
# |    n_updates            | 4870        |
# |    policy_gradient_loss | -0.000282   |
# |    value_loss           | 0.0358      |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1081          |
# |    iterations           | 489           |
# |    time_elapsed         | 925           |
# |    total_timesteps      | 1001472       |
# | train/                  |               |
# |    approx_kl            | 0.00061876816 |
# |    clip_fraction        | 0.00459       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0287       |
# |    explained_variance   | 0.145         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0302        |
# |    n_updates            | 4880          |
# |    policy_gradient_loss | 1.07e-05      |
# |    value_loss           | 0.0368        |
# -------------------------------------------

# %%
PPO_path = os.path.join('Saved Models', 'PPO_1M')
model.save(PPO_path)

# %%
del model

# %%
model = PPO.load(PPO_path)

# %%
evaluate_policy(model, train_env, n_eval_episodes=10)
# Out:
# (np.float64(0.6), np.float64(0.4898979485566356))

# %%
test_env = gym.make("FrozenLake-v1", render_mode='human')
episodes = 5
for episode in range(episodes):
    obs, _ = test_env.reset()
    done = False
    truncated = False
    score = 0

    while not done and not truncated:
        action, _ = model.predict(obs)
        n_state, reward, done, truncated, info = test_env.step(int(action))
        score += reward
    print(f"Episode: {episode+1} Score: {score}")
test_env.close()
# Out:
# Episode: 1 Score: 0.0
# Episode: 2 Score: 0.0
# Episode: 3 Score: 0.0
# Episode: 4 Score: 0.0
# Episode: 5 Score: 0.0

# %%
from stable_baselines3 import DQN
model = DQN('MlpPolicy', train_env, verbose=1)
model.learn(total_timesteps=50000)
# Out:
# Using cpu device
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 8401     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 18       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.991    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 22402    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 48       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.982    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 6876     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 94       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.977    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 3431     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 123      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00331  |
# |    n_updates        | 5        |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.971    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 2459     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 154      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00332  |
# |    n_updates        | 13       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.966    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 2195     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 178      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0038   |
# |    n_updates        | 19       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.961    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 2187     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 204      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00243  |
# |    n_updates        | 25       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.957    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 1943     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 228      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00377  |
# |    n_updates        | 31       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.954    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 1867     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 244      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0032   |
# |    n_updates        | 35       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.944    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 1770     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 295      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00127  |
# |    n_updates        | 48       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.941    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 1710     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 309      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00277  |
# |    n_updates        | 52       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.936    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 1680     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 337      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0136   |
# |    n_updates        | 59       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.929    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 1655     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 372      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0012   |
# |    n_updates        | 67       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.926    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 1613     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 392      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00328  |
# |    n_updates        | 72       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.922    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 1584     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 409      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00219  |
# |    n_updates        | 77       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.914    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 1577     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 453      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00226  |
# |    n_updates        | 88       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.907    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 1561     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 489      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00246  |
# |    n_updates        | 97       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.903    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 1500     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 512      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00148  |
# |    n_updates        | 102      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.898    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 1463     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 538      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0024   |
# |    n_updates        | 109      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.89     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 1454     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 581      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00165  |
# |    n_updates        | 120      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.884    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 1440     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 608      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00175  |
# |    n_updates        | 126      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.879    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 1429     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 638      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00159  |
# |    n_updates        | 134      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.876    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 1428     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 654      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00167  |
# |    n_updates        | 138      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.869    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 1434     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 691      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000835 |
# |    n_updates        | 147      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.865    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 1427     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 710      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00209  |
# |    n_updates        | 152      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.854    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 1431     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 766      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00228  |
# |    n_updates        | 166      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.851    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 1427     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 786      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0013   |
# |    n_updates        | 171      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.843    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 1428     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 828      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00193  |
# |    n_updates        | 181      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.836    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 1428     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 864      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00097  |
# |    n_updates        | 190      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.832    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 1424     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 882      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000754 |
# |    n_updates        | 195      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.829    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 1418     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 902      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0232   |
# |    n_updates        | 200      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.824    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 1412     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 926      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0016   |
# |    n_updates        | 206      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.819    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 1416     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 951      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00147  |
# |    n_updates        | 212      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.812    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 1415     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 991      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00104  |
# |    n_updates        | 222      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.809    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 1412     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1006     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00114  |
# |    n_updates        | 226      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.806    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 1407     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1021     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00146  |
# |    n_updates        | 230      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.802    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 1415     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1040     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00161  |
# |    n_updates        | 234      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.797    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 1404     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1070     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00168  |
# |    n_updates        | 242      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.79     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 1406     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1104     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00104  |
# |    n_updates        | 250      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.787    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 1401     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1121     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0013   |
# |    n_updates        | 255      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.78     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 1402     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1157     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00117  |
# |    n_updates        | 264      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.773    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 1400     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1193     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00105  |
# |    n_updates        | 273      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.768    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 1401     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1222     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00126  |
# |    n_updates        | 280      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.761    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 1405     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1260     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00131  |
# |    n_updates        | 289      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.755    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 1405     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1288     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00141  |
# |    n_updates        | 296      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.752    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 1403     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1305     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00139  |
# |    n_updates        | 301      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.742    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 1407     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1358     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00126  |
# |    n_updates        | 314      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.739    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 1408     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1372     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000841 |
# |    n_updates        | 317      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.732    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 1387     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1410     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00117  |
# |    n_updates        | 327      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.727    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 1361     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1437     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00162  |
# |    n_updates        | 334      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.722    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 1364     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1464     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000918 |
# |    n_updates        | 340      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.714    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 1359     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1505     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000572 |
# |    n_updates        | 351      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.709    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 1358     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1530     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000924 |
# |    n_updates        | 357      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.701    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 1359     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1573     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00142  |
# |    n_updates        | 368      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.696    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 1359     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1600     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0011   |
# |    n_updates        | 374      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.69     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 1360     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1630     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00117  |
# |    n_updates        | 382      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.683    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 1361     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1671     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00139  |
# |    n_updates        | 392      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.674    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 1360     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1717     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00072  |
# |    n_updates        | 404      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.666    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 1361     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1759     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00126  |
# |    n_updates        | 414      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.66     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 1348     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1789     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00113  |
# |    n_updates        | 422      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.651    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 1352     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1837     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000593 |
# |    n_updates        | 434      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.645    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 1347     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1870     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0116   |
# |    n_updates        | 442      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.636    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 1344     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1917     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000774 |
# |    n_updates        | 454      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.633    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 1345     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1932     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000976 |
# |    n_updates        | 457      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.623    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 1342     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1985     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000642 |
# |    n_updates        | 471      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.617    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 1340     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2017     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000736 |
# |    n_updates        | 479      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.61     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 1337     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2053     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000814 |
# |    n_updates        | 488      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.604    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 1335     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2084     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000589 |
# |    n_updates        | 495      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.599    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 1313     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2110     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00161  |
# |    n_updates        | 502      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.587    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 1313     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2175     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000834 |
# |    n_updates        | 518      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.581    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 1308     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2203     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0112   |
# |    n_updates        | 525      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.578    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 1306     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2223     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000944 |
# |    n_updates        | 530      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.574    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 1304     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2244     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000597 |
# |    n_updates        | 535      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.564    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 1303     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2297     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00131  |
# |    n_updates        | 549      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.558    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 1304     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2328     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000969 |
# |    n_updates        | 556      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.555    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 1302     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2343     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0115   |
# |    n_updates        | 560      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.551    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 1297     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2365     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0114   |
# |    n_updates        | 566      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.538    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 1298     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2434     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00088  |
# |    n_updates        | 583      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.528    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 1296     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2482     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00085  |
# |    n_updates        | 595      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.523    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 1293     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2511     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000718 |
# |    n_updates        | 602      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.515    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 1292     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2553     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00116  |
# |    n_updates        | 613      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.511    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 1292     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2574     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000788 |
# |    n_updates        | 618      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.504    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 1288     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2612     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000815 |
# |    n_updates        | 627      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.497    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 1276     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2647     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000773 |
# |    n_updates        | 636      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.487    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 1275     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2701     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000647 |
# |    n_updates        | 650      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.481    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 1270     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2734     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000862 |
# |    n_updates        | 658      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.469    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 1274     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2796     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0104   |
# |    n_updates        | 673      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.458    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 1276     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2852     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000499 |
# |    n_updates        | 687      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.451    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 1273     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2890     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00102  |
# |    n_updates        | 697      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.441    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 1279     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2942     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000804 |
# |    n_updates        | 710      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.436    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 1274     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2970     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000858 |
# |    n_updates        | 717      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.412    |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 1289     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3094     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000292 |
# |    n_updates        | 748      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.398    |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 1292     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3166     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0104   |
# |    n_updates        | 766      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.39     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 1286     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3208     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000486 |
# |    n_updates        | 776      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.384    |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 1286     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3241     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00145  |
# |    n_updates        | 785      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.375    |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 1287     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3292     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00974  |
# |    n_updates        | 797      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.365    |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 1289     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3342     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000407 |
# |    n_updates        | 810      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.36     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 1275     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3369     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000968 |
# |    n_updates        | 817      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.349    |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 1276     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3424     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00178  |
# |    n_updates        | 830      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.339    |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 1271     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3480     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000756 |
# |    n_updates        | 844      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.323    |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 1260     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3563     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000611 |
# |    n_updates        | 865      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.312    |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 1254     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3621     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000709 |
# |    n_updates        | 880      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.303    |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 1245     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3666     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000818 |
# |    n_updates        | 891      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.296    |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 1240     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3703     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000845 |
# |    n_updates        | 900      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.286    |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 1234     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3757     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00116  |
# |    n_updates        | 914      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.277    |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 1232     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3807     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000833 |
# |    n_updates        | 926      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.267    |
# | time/               |          |
# ...
# |    n_updates        | 11345    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1572     |
# |    fps              | 1238     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 45602    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00515  |
# |    n_updates        | 11375    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1576     |
# |    fps              | 1238     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 45674    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00246  |
# |    n_updates        | 11393    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1580     |
# |    fps              | 1238     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 45791    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00375  |
# |    n_updates        | 11422    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1584     |
# |    fps              | 1239     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 45961    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00295  |
# |    n_updates        | 11465    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1588     |
# |    fps              | 1239     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 46167    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00451  |
# |    n_updates        | 11516    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1592     |
# |    fps              | 1239     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 46365    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00102  |
# |    n_updates        | 11566    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1596     |
# |    fps              | 1239     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 46490    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00593  |
# |    n_updates        | 11597    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1600     |
# |    fps              | 1240     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 46578    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0023   |
# |    n_updates        | 11619    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1604     |
# |    fps              | 1240     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 46701    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00181  |
# |    n_updates        | 11650    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1608     |
# |    fps              | 1240     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 46796    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00225  |
# |    n_updates        | 11673    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1612     |
# |    fps              | 1240     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 46896    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00254  |
# |    n_updates        | 11698    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1616     |
# |    fps              | 1240     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 46974    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000335 |
# |    n_updates        | 11718    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1620     |
# |    fps              | 1240     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 47038    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00313  |
# |    n_updates        | 11734    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1624     |
# |    fps              | 1240     |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 47184    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00233  |
# |    n_updates        | 11770    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1628     |
# |    fps              | 1240     |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 47264    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00179  |
# |    n_updates        | 11790    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1632     |
# |    fps              | 1240     |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 47369    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00173  |
# |    n_updates        | 11817    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1636     |
# |    fps              | 1240     |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 47506    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000184 |
# |    n_updates        | 11851    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1640     |
# |    fps              | 1240     |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 47636    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00435  |
# |    n_updates        | 11883    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1644     |
# |    fps              | 1240     |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 47764    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.002    |
# |    n_updates        | 11915    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1648     |
# |    fps              | 1241     |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 47931    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00284  |
# |    n_updates        | 11957    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1652     |
# |    fps              | 1241     |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 48041    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000518 |
# |    n_updates        | 11985    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1656     |
# |    fps              | 1241     |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 48102    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00299  |
# |    n_updates        | 12000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1660     |
# |    fps              | 1241     |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 48331    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00527  |
# |    n_updates        | 12057    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1664     |
# |    fps              | 1241     |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 48553    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00165  |
# |    n_updates        | 12113    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1668     |
# |    fps              | 1242     |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 48680    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00321  |
# |    n_updates        | 12144    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1672     |
# |    fps              | 1242     |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 48839    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00326  |
# |    n_updates        | 12184    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1676     |
# |    fps              | 1241     |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 48901    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000535 |
# |    n_updates        | 12200    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1680     |
# |    fps              | 1242     |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 49115    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00122  |
# |    n_updates        | 12253    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1684     |
# |    fps              | 1242     |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 49189    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00143  |
# |    n_updates        | 12272    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1688     |
# |    fps              | 1241     |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 49360    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00568  |
# |    n_updates        | 12314    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1692     |
# |    fps              | 1241     |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 49440    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.001    |
# |    n_updates        | 12334    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1696     |
# |    fps              | 1241     |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 49510    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00269  |
# |    n_updates        | 12352    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1700     |
# |    fps              | 1241     |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 49711    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00274  |
# |    n_updates        | 12402    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1704     |
# |    fps              | 1239     |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 49787    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00462  |
# |    n_updates        | 12421    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1708     |
# |    fps              | 1239     |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 49843    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000937 |
# |    n_updates        | 12435    |
# ----------------------------------

# %%
DQN_path = os.path.join('Saved Models', 'DQN_50K')
model.save(DQN_path)

# %%
del model

# %%
model = DQN.load(DQN_path)

# %%
evaluate_policy(model, train_env, n_eval_episodes=10)
# Out:
# (np.float64(0.0), np.float64(0.0))

# %%
test_env = gym.make("FrozenLake-v1", render_mode='human')
episodes = 5
for episode in range(episodes):
    obs, _ = test_env.reset()
    done = False
    truncated = False
    score = 0

    while not done and not truncated:
        action, _ = model.predict(obs)
        n_state, reward, done, truncated, info = test_env.step(int(action))
        score += reward
    print(f"Episode: {episode+1} Score: {score}")
test_env.close()
# Out:
# Episode: 1 Score: 0.0
# Episode: 2 Score: 0.0
# Episode: 3 Score: 0.0
# Episode: 4 Score: 0.0
# Episode: 5 Score: 0.0

# %%
from stable_baselines3 import A2C
model = A2C('MlpPolicy', train_env, verbose=1)
model.learn(100000)
# Out:
# Using cpu device
# ------------------------------------
# | time/                 |          |
# |    fps                | 763      |
# |    iterations         | 100      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -1.36    |
# |    explained_variance | -936     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | 0.000238 |
# |    value_loss         | 1.91e-07 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 782       |
# |    iterations         | 200       |
# |    time_elapsed       | 1         |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -1.38     |
# |    explained_variance | -86.8     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199       |
# |    policy_loss        | -0.000961 |
# |    value_loss         | 1.13e-06  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 780      |
# |    iterations         | 300      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -1.38    |
# |    explained_variance | -43.4    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | 0.0052   |
# |    value_loss         | 6.18e-05 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 754       |
# |    iterations         | 400       |
# |    time_elapsed       | 2         |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -1.38     |
# |    explained_variance | -7.27e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 399       |
# |    policy_loss        | 0.00113   |
# |    value_loss         | 3.68e-06  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 757      |
# |    iterations         | 500      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -1.38    |
# |    explained_variance | -99.1    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | -0.0178  |
# |    value_loss         | 0.000302 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 765      |
# |    iterations         | 600      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -1.38    |
# |    explained_variance | nan      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | -0.0324  |
# |    value_loss         | 0.000601 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 773       |
# |    iterations         | 700       |
# |    time_elapsed       | 4         |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -1.37     |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 699       |
# |    policy_loss        | -0.000126 |
# |    value_loss         | 2.62e-08  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 786      |
# |    iterations         | 800      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -1.37    |
# |    explained_variance | -0.163   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | 0.000221 |
# |    value_loss         | 3.61e-08 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 793      |
# |    iterations         | 900      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -1.38    |
# |    explained_variance | -104     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | -0.00576 |
# |    value_loss         | 0.000211 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 799       |
# |    iterations         | 1000      |
# |    time_elapsed       | 6         |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -1.38     |
# |    explained_variance | -6.12e+05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 999       |
# |    policy_loss        | -0.0005   |
# |    value_loss         | 1.14e-05  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 805      |
# |    iterations         | 1100     |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -1.37    |
# |    explained_variance | -0.291   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | -0.0763  |
# |    value_loss         | 0.00469  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 809      |
# |    iterations         | 1200     |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -1.34    |
# |    explained_variance | -124     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | -0.0463  |
# |    value_loss         | 0.00166  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 814      |
# |    iterations         | 1300     |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -1.36    |
# |    explained_variance | nan      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | 0.0112   |
# |    value_loss         | 8.99e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 818      |
# |    iterations         | 1400     |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -1.34    |
# |    explained_variance | -2.45    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | 5.86e-06 |
# |    value_loss         | 1.09e-09 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 821      |
# |    iterations         | 1500     |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -1.31    |
# |    explained_variance | -5.92    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | -0.0872  |
# |    value_loss         | 0.00557  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 825       |
# |    iterations         | 1600      |
# |    time_elapsed       | 9         |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -1.33     |
# |    explained_variance | -1.46e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1599      |
# |    policy_loss        | -0.0119   |
# |    value_loss         | 0.00125   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 827       |
# |    iterations         | 1700      |
# |    time_elapsed       | 10        |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -1.31     |
# |    explained_variance | -2.92e+05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1699      |
# |    policy_loss        | -0.112    |
# |    value_loss         | 0.00482   |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 820      |
# |    iterations         | 1800     |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -1.24    |
# |    explained_variance | -459     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | 0.000703 |
# |    value_loss         | 3.89e-07 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 811      |
# |    iterations         | 1900     |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 9500     |
# | train/                |          |
# |    entropy_loss       | -1.32    |
# |    explained_variance | -1.76    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | -0.00116 |
# |    value_loss         | 9.82e-06 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 811      |
# |    iterations         | 2000     |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -1.29    |
# |    explained_variance | nan      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1999     |
# |    policy_loss        | -0.0579  |
# |    value_loss         | 0.0027   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 811      |
# |    iterations         | 2100     |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 10500    |
# | train/                |          |
# |    entropy_loss       | -1.28    |
# |    explained_variance | -256     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2099     |
# |    policy_loss        | 0.00659  |
# |    value_loss         | 4.83e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 813      |
# |    iterations         | 2200     |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 11000    |
# | train/                |          |
# |    entropy_loss       | -1.27    |
# |    explained_variance | 0.194    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2199     |
# |    policy_loss        | 0.00704  |
# |    value_loss         | 0.000231 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 816      |
# |    iterations         | 2300     |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 11500    |
# | train/                |          |
# |    entropy_loss       | -1.21    |
# |    explained_variance | 0.818    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2299     |
# |    policy_loss        | -0.0311  |
# |    value_loss         | 0.000718 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 817      |
# |    iterations         | 2400     |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -1.13    |
# |    explained_variance | nan      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2399     |
# |    policy_loss        | -0.0109  |
# |    value_loss         | 0.000132 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 812      |
# |    iterations         | 2500     |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 12500    |
# | train/                |          |
# |    entropy_loss       | -1.07    |
# |    explained_variance | -0.469   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2499     |
# |    policy_loss        | -0.0466  |
# |    value_loss         | 0.00169  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 805      |
# |    iterations         | 2600     |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 13000    |
# | train/                |          |
# |    entropy_loss       | -1.07    |
# |    explained_variance | -111     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2599     |
# |    policy_loss        | -0.0119  |
# |    value_loss         | 0.000248 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 798       |
# |    iterations         | 2700      |
# |    time_elapsed       | 16        |
# |    total_timesteps    | 13500     |
# | train/                |           |
# |    entropy_loss       | -0.668    |
# |    explained_variance | -32.2     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2699      |
# |    policy_loss        | -8.37e-05 |
# |    value_loss         | 1.02e-06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 793       |
# |    iterations         | 2800      |
# |    time_elapsed       | 17        |
# |    total_timesteps    | 14000     |
# | train/                |           |
# |    entropy_loss       | -1.26     |
# |    explained_variance | -1.25e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2799      |
# |    policy_loss        | -0.027    |
# |    value_loss         | 0.000317  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 790      |
# |    iterations         | 2900     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 14500    |
# | train/                |          |
# |    entropy_loss       | -0.242   |
# |    explained_variance | -70.4    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2899     |
# |    policy_loss        | 0.00333  |
# |    value_loss         | 0.00278  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 790      |
# |    iterations         | 3000     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.396   |
# |    explained_variance | -0.112   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2999     |
# |    policy_loss        | -0.00179 |
# |    value_loss         | 3.15e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 786      |
# |    iterations         | 3100     |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 15500    |
# | train/                |          |
# |    entropy_loss       | -0.269   |
# |    explained_variance | -97.3    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3099     |
# |    policy_loss        | -0.00154 |
# |    value_loss         | 0.000621 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 785      |
# |    iterations         | 3200     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -0.894   |
# |    explained_variance | -1.32    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3199     |
# |    policy_loss        | -0.00686 |
# |    value_loss         | 0.000424 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 783      |
# |    iterations         | 3300     |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 16500    |
# | train/                |          |
# |    entropy_loss       | -0.362   |
# |    explained_variance | -187     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3299     |
# |    policy_loss        | 0.0178   |
# |    value_loss         | 0.0248   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 778      |
# |    iterations         | 3400     |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 17000    |
# | train/                |          |
# |    entropy_loss       | -0.193   |
# |    explained_variance | nan      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3399     |
# |    policy_loss        | -0.0367  |
# |    value_loss         | 0.0115   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 776      |
# |    iterations         | 3500     |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 17500    |
# | train/                |          |
# |    entropy_loss       | -0.118   |
# |    explained_variance | -0.00734 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3499     |
# |    policy_loss        | -0.00515 |
# |    value_loss         | 2.13e-05 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 774       |
# |    iterations         | 3600      |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 18000     |
# | train/                |           |
# |    entropy_loss       | -0.0534   |
# |    explained_variance | -14.2     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3599      |
# |    policy_loss        | -1.19e-05 |
# |    value_loss         | 1.36e-05  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 773      |
# |    iterations         | 3700     |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 18500    |
# | train/                |          |
# |    entropy_loss       | -0.133   |
# |    explained_variance | -85.7    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3699     |
# |    policy_loss        | 0.00134  |
# |    value_loss         | 0.00463  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 772      |
# |    iterations         | 3800     |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 19000    |
# | train/                |          |
# |    entropy_loss       | -0.249   |
# |    explained_variance | -33.8    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3799     |
# |    policy_loss        | -0.0425  |
# |    value_loss         | 0.0176   |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 769       |
# |    iterations         | 3900      |
# |    time_elapsed       | 25        |
# |    total_timesteps    | 19500     |
# | train/                |           |
# |    entropy_loss       | -0.0353   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3899      |
# |    policy_loss        | -1.92e-05 |
# |    value_loss         | 1.97e-05  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 765      |
# |    iterations         | 4000     |
# |    time_elapsed       | 26       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.0318  |
# |    explained_variance | -331     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3999     |
# |    policy_loss        | 0.000215 |
# |    value_loss         | 0.00206  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 767       |
# |    iterations         | 4100      |
# |    time_elapsed       | 26        |
# |    total_timesteps    | 20500     |
# | train/                |           |
# |    entropy_loss       | -0.0441   |
# |    explained_variance | -2.73     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4099      |
# |    policy_loss        | -1.51e-05 |
# |    value_loss         | 7.15e-06  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 761      |
# |    iterations         | 4200     |
# |    time_elapsed       | 27       |
# |    total_timesteps    | 21000    |
# | train/                |          |
# |    entropy_loss       | -0.151   |
# |    explained_variance | -59.7    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4199     |
# |    policy_loss        | 0.0239   |
# |    value_loss         | 0.26     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 757      |
# |    iterations         | 4300     |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 21500    |
# | train/                |          |
# |    entropy_loss       | -0.0926  |
# |    explained_variance | -0.013   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4299     |
# |    policy_loss        | -0.00596 |
# |    value_loss         | 0.0435   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 758      |
# |    iterations         | 4400     |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 22000    |
# | train/                |          |
# |    entropy_loss       | -0.135   |
# |    explained_variance | 0.285    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4399     |
# |    policy_loss        | -0.0281  |
# |    value_loss         | 0.00436  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 757      |
# |    iterations         | 4500     |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 22500    |
# | train/                |          |
# |    entropy_loss       | -0.342   |
# |    explained_variance | -2.38    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4499     |
# |    policy_loss        | -0.0206  |
# |    value_loss         | 0.0137   |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 756       |
# |    iterations         | 4600      |
# |    time_elapsed       | 30        |
# |    total_timesteps    | 23000     |
# | train/                |           |
# |    entropy_loss       | -0.603    |
# |    explained_variance | -1.74e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4599      |
# |    policy_loss        | -0.0369   |
# |    value_loss         | 0.0148    |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 757      |
# |    iterations         | 4700     |
# |    time_elapsed       | 31       |
# |    total_timesteps    | 23500    |
# | train/                |          |
# |    entropy_loss       | -0.329   |
# |    explained_variance | -9.8     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4699     |
# |    policy_loss        | -0.114   |
# |    value_loss         | 0.147    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 757      |
# |    iterations         | 4800     |
# |    time_elapsed       | 31       |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -0.141   |
# |    explained_variance | nan      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4799     |
# |    policy_loss        | -0.0877  |
# |    value_loss         | 0.0256   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 756      |
# |    iterations         | 4900     |
# |    time_elapsed       | 32       |
# |    total_timesteps    | 24500    |
# | train/                |          |
# |    entropy_loss       | -0.198   |
# |    explained_variance | -237     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4899     |
# |    policy_loss        | 0.0169   |
# |    value_loss         | 0.0728   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 758      |
# |    iterations         | 5000     |
# |    time_elapsed       | 32       |
# |    total_timesteps    | 25000    |
# | train/                |          |
# |    entropy_loss       | -0.075   |
# |    explained_variance | -2.66    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4999     |
# |    policy_loss        | 3.16e-05 |
# |    value_loss         | 5.68e-06 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 759       |
# |    iterations         | 5100      |
# |    time_elapsed       | 33        |
# |    total_timesteps    | 25500     |
# | train/                |           |
# |    entropy_loss       | -0.354    |
# |    explained_variance | -2.13e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5099      |
# |    policy_loss        | -0.132    |
# |    value_loss         | 0.0691    |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 760       |
# |    iterations         | 5200      |
# |    time_elapsed       | 34        |
# |    total_timesteps    | 26000     |
# | train/                |           |
# |    entropy_loss       | -0.00627  |
# |    explained_variance | -5.19     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5199      |
# |    policy_loss        | -1.95e-06 |
# |    value_loss         | 4.67e-05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 759       |
# |    iterations         | 5300      |
# |    time_elapsed       | 34        |
# |    total_timesteps    | 26500     |
# | train/                |           |
# |    entropy_loss       | -0.00614  |
# |    explained_variance | -38.4     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5299      |
# |    policy_loss        | -1.27e-05 |
# |    value_loss         | 0.000393  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 760       |
# |    iterations         | 5400      |
# |    time_elapsed       | 35        |
# |    total_timesteps    | 27000     |
# | train/                |           |
# |    entropy_loss       | -0.00441  |
# |    explained_variance | -0.67     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5399      |
# |    policy_loss        | -9.67e-07 |
# |    value_loss         | 7.28e-06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 762       |
# |    iterations         | 5500      |
# |    time_elapsed       | 36        |
# |    total_timesteps    | 27500     |
# | train/                |           |
# |    entropy_loss       | -0.264    |
# |    explained_variance | -46.7     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5499      |
# |    policy_loss        | -0.000845 |
# |    value_loss         | 0.000295  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 762      |
# |    iterations         | 5600     |
# |    time_elapsed       | 36       |
# |    total_timesteps    | 28000    |
# | train/                |          |
# |    entropy_loss       | -0.0993  |
# |    explained_variance | 0.195    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5599     |
# |    policy_loss        | -0.00861 |
# |    value_loss         | 0.0105   |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 763       |
# |    iterations         | 5700      |
# |    time_elapsed       | 37        |
# |    total_timesteps    | 28500     |
# | train/                |           |
# |    entropy_loss       | -0.00312  |
# |    explained_variance | -1.17     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5699      |
# |    policy_loss        | -4.17e-07 |
# |    value_loss         | 7.79e-06  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 765      |
# |    iterations         | 5800     |
# |    time_elapsed       | 37       |
# |    total_timesteps    | 29000    |
# | train/                |          |
# |    entropy_loss       | -0.315   |
# |    explained_variance | -13      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5799     |
# |    policy_loss        | 0.0217   |
# |    value_loss         | 0.0255   |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 765       |
# |    iterations         | 5900      |
# |    time_elapsed       | 38        |
# |    total_timesteps    | 29500     |
# | train/                |           |
# |    entropy_loss       | -0.313    |
# |    explained_variance | -3.3e+03  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5899      |
# |    policy_loss        | -0.000137 |
# |    value_loss         | 0.0084    |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 766      |
# |    iterations         | 6000     |
# |    time_elapsed       | 39       |
# |    total_timesteps    | 30000    |
# | train/                |          |
# |    entropy_loss       | -0.401   |
# |    explained_variance | -253     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5999     |
# |    policy_loss        | 0.189    |
# |    value_loss         | 0.186    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 766      |
# |    iterations         | 6100     |
# |    time_elapsed       | 39       |
# |    total_timesteps    | 30500    |
# | train/                |          |
# |    entropy_loss       | -0.00374 |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6099     |
# |    policy_loss        | 2.08e-06 |
# |    value_loss         | 4.09e-05 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 767       |
# |    iterations         | 6200      |
# |    time_elapsed       | 40        |
# |    total_timesteps    | 31000     |
# | train/                |           |
# |    entropy_loss       | -0.00248  |
# |    explained_variance | -34       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6199      |
# |    policy_loss        | -1.39e-05 |
# |    value_loss         | 0.00333   |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 769      |
# |    iterations         | 6300     |
# |    time_elapsed       | 40       |
# |    total_timesteps    | 31500    |
# | train/                |          |
# |    entropy_loss       | -0.149   |
# |    explained_variance | -14.1    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6299     |
# |    policy_loss        | 0.0401   |
# |    value_loss         | 0.0514   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 771      |
# |    iterations         | 6400     |
# |    time_elapsed       | 41       |
# |    total_timesteps    | 32000    |
# | train/                |          |
# |    entropy_loss       | -0.152   |
# |    explained_variance | -246     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6399     |
# |    policy_loss        | -0.0115  |
# |    value_loss         | 0.0772   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 773      |
# |    iterations         | 6500     |
# |    time_elapsed       | 42       |
# |    total_timesteps    | 32500    |
# | train/                |          |
# |    entropy_loss       | -0.143   |
# |    explained_variance | -4.17    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6499     |
# |    policy_loss        | -0.0322  |
# |    value_loss         | 0.0186   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 774      |
# |    iterations         | 6600     |
# |    time_elapsed       | 42       |
# |    total_timesteps    | 33000    |
# | train/                |          |
# |    entropy_loss       | -0.157   |
# |    explained_variance | -25.8    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6599     |
# |    policy_loss        | 0.00204  |
# |    value_loss         | 0.000474 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 775      |
# |    iterations         | 6700     |
# |    time_elapsed       | 43       |
# |    total_timesteps    | 33500    |
# | train/                |          |
# |    entropy_loss       | -0.153   |
# |    explained_variance | -76.6    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6699     |
# |    policy_loss        | 0.00423  |
# |    value_loss         | 0.000424 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 777      |
# |    iterations         | 6800     |
# |    time_elapsed       | 43       |
# |    total_timesteps    | 34000    |
# | train/                |          |
# |    entropy_loss       | -0.299   |
# |    explained_variance | -194     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6799     |
# |    policy_loss        | 0.0117   |
# |    value_loss         | 0.103    |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 778       |
# |    iterations         | 6900      |
# |    time_elapsed       | 44        |
# |    total_timesteps    | 34500     |
# | train/                |           |
# |    entropy_loss       | -0.359    |
# |    explained_variance | -4.84     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6899      |
# |    policy_loss        | -0.000418 |
# |    value_loss         | 4.81e-05  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 779      |
# |    iterations         | 7000     |
# |    time_elapsed       | 44       |
# |    total_timesteps    | 35000    |
# | train/                |          |
# |    entropy_loss       | -0.00136 |
# |    explained_variance | -0.274   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6999     |
# |    policy_loss        | 6.26e-06 |
# |    value_loss         | 0.00245  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 781       |
# |    iterations         | 7100      |
# |    time_elapsed       | 45        |
# |    total_timesteps    | 35500     |
# | train/                |           |
# |    entropy_loss       | -0.123    |
# |    explained_variance | -0.123    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7099      |
# |    policy_loss        | -0.000642 |
# |    value_loss         | 8.82e-05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 782       |
# |    iterations         | 7200      |
# |    time_elapsed       | 46        |
# |    total_timesteps    | 36000     |
# | train/                |           |
# |    entropy_loss       | -0.00133  |
# |    explained_variance | -8.07     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7199      |
# |    policy_loss        | -1.78e-06 |
# |    value_loss         | 0.000408  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 783      |
# |    iterations         | 7300     |
# |    time_elapsed       | 46       |
# |    total_timesteps    | 36500    |
# | train/                |          |
# |    entropy_loss       | -0.106   |
# |    explained_variance | -0.104   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7299     |
# |    policy_loss        | -0.286   |
# |    value_loss         | 0.0951   |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 785       |
# |    iterations         | 7400      |
# |    time_elapsed       | 47        |
# |    total_timesteps    | 37000     |
# | train/                |           |
# |    entropy_loss       | -0.00167  |
# |    explained_variance | -1.01     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7399      |
# |    policy_loss        | -2.63e-06 |
# |    value_loss         | 0.000362  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 786      |
# |    iterations         | 7500     |
# |    time_elapsed       | 47       |
# |    total_timesteps    | 37500    |
# | train/                |          |
# |    entropy_loss       | -0.121   |
# |    explained_variance | -28.1    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7499     |
# |    policy_loss        | 0.0018   |
# |    value_loss         | 0.00794  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 787      |
# |    iterations         | 7600     |
# |    time_elapsed       | 48       |
# |    total_timesteps    | 38000    |
# | train/                |          |
# |    entropy_loss       | -0.0545  |
# |    explained_variance | -0.378   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7599     |
# |    policy_loss        | 0.000654 |
# |    value_loss         | 0.00609  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 788       |
# |    iterations         | 7700      |
# |    time_elapsed       | 48        |
# |    total_timesteps    | 38500     |
# | train/                |           |
# |    entropy_loss       | -0.0351   |
# |    explained_variance | -1.82     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7699      |
# |    policy_loss        | -6.01e-05 |
# |    value_loss         | 0.000163  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 790      |
# |    iterations         | 7800     |
# |    time_elapsed       | 49       |
# |    total_timesteps    | 39000    |
# | train/                |          |
# |    entropy_loss       | -0.0014  |
# |    explained_variance | 0.0887   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7799     |
# |    policy_loss        | -1.5e-06 |
# |    value_loss         | 0.000159 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 791      |
# |    iterations         | 7900     |
# |    time_elapsed       | 49       |
# |    total_timesteps    | 39500    |
# | train/                |          |
# |    entropy_loss       | -0.0436  |
# |    explained_variance | -220     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7899     |
# |    policy_loss        | -0.00232 |
# |    value_loss         | 0.116    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 792      |
# |    iterations         | 8000     |
# |    time_elapsed       | 50       |
# |    total_timesteps    | 40000    |
# | train/                |          |
# |    entropy_loss       | -0.051   |
# |    explained_variance | 0.103    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7999     |
# |    policy_loss        | 0.155    |
# |    value_loss         | 0.0154   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 792      |
# |    iterations         | 8100     |
# |    time_elapsed       | 51       |
# |    total_timesteps    | 40500    |
# | train/                |          |
# |    entropy_loss       | -0.0341  |
# |    explained_variance | -2.81    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8099     |
# |    policy_loss        | -0.00024 |
# |    value_loss         | 0.000975 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 793      |
# |    iterations         | 8200     |
# |    time_elapsed       | 51       |
# |    total_timesteps    | 41000    |
# | train/                |          |
# |    entropy_loss       | -0.0422  |
# |    explained_variance | -0.0772  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8199     |
# |    policy_loss        | -0.422   |
# |    value_loss         | 0.185    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 792      |
# |    iterations         | 8300     |
# |    time_elapsed       | 52       |
# |    total_timesteps    | 41500    |
# | train/                |          |
# |    entropy_loss       | -0.0257  |
# |    explained_variance | -9.96    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8299     |
# |    policy_loss        | -0.00022 |
# |    value_loss         | 0.00239  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 794       |
# |    iterations         | 8400      |
# |    time_elapsed       | 52        |
# |    total_timesteps    | 42000     |
# | train/                |           |
# |    entropy_loss       | -0.00131  |
# |    explained_variance | -0.0821   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8399      |
# |    policy_loss        | -2.17e-06 |
# |    value_loss         | 0.000393  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 793       |
# |    iterations         | 8500      |
# |    time_elapsed       | 53        |
# |    total_timesteps    | 42500     |
# | train/                |           |
# |    entropy_loss       | -0.00134  |
# |    explained_variance | -0.0274   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8499      |
# |    policy_loss        | -2.83e-06 |
# |    value_loss         | 0.000568  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 793      |
# |    iterations         | 8600     |
# |    time_elapsed       | 54       |
# |    total_timesteps    | 43000    |
# | train/                |          |
# |    entropy_loss       | -0.085   |
# |    explained_variance | -97.2    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8599     |
# |    policy_loss        | -0.00268 |
# |    value_loss         | 0.0232   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 789      |
# |    iterations         | 8700     |
# |    time_elapsed       | 55       |
# |    total_timesteps    | 43500    |
# | train/                |          |
# |    entropy_loss       | -0.0501  |
# |    explained_variance | 0.81     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8699     |
# |    policy_loss        | 0.00141  |
# |    value_loss         | 0.0179   |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 788       |
# |    iterations         | 8800      |
# |    time_elapsed       | 55        |
# |    total_timesteps    | 44000     |
# | train/                |           |
# |    entropy_loss       | -0.00163  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8799      |
# |    policy_loss        | -3.58e-07 |
# |    value_loss         | 4.96e-05  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 787      |
# |    iterations         | 8900     |
# |    time_elapsed       | 56       |
# |    total_timesteps    | 44500    |
# | train/                |          |
# |    entropy_loss       | -0.0383  |
# |    explained_variance | -77.3    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8899     |
# |    policy_loss        | -0.0015  |
# |    value_loss         | 0.0506   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 786      |
# |    iterations         | 9000     |
# |    time_elapsed       | 57       |
# |    total_timesteps    | 45000    |
# | train/                |          |
# |    entropy_loss       | -0.00165 |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8999     |
# |    policy_loss        | 2.43e-06 |
# |    value_loss         | 0.000266 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 786      |
# |    iterations         | 9100     |
# |    time_elapsed       | 57       |
# |    total_timesteps    | 45500    |
# | train/                |          |
# |    entropy_loss       | -0.0336  |
# |    explained_variance | -11.4    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9099     |
# |    policy_loss        | 0.000167 |
# |    value_loss         | 0.00127  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 786      |
# |    iterations         | 9200     |
# |    time_elapsed       | 58       |
# |    total_timesteps    | 46000    |
# | train/                |          |
# |    entropy_loss       | -0.00193 |
# |    explained_variance | -0.0475  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9199     |
# |    policy_loss        | 9.87e-07 |
# ...
# |    policy_loss        | 0.000142 |
# |    value_loss         | 0.0568   |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 795       |
# |    iterations         | 17100     |
# |    time_elapsed       | 107       |
# |    total_timesteps    | 85500     |
# | train/                |           |
# |    entropy_loss       | -0.000529 |
# |    explained_variance | -0.941    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 17099     |
# |    policy_loss        | -1.09e-06 |
# |    value_loss         | 0.000407  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 795       |
# |    iterations         | 17200     |
# |    time_elapsed       | 108       |
# |    total_timesteps    | 86000     |
# | train/                |           |
# |    entropy_loss       | -0.000284 |
# |    explained_variance | -0.655    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 17199     |
# |    policy_loss        | 7.03e-08  |
# |    value_loss         | 6.17e-05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 796       |
# |    iterations         | 17300     |
# |    time_elapsed       | 108       |
# |    total_timesteps    | 86500     |
# | train/                |           |
# |    entropy_loss       | -0.000308 |
# |    explained_variance | -2.36     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 17299     |
# |    policy_loss        | 1.22e-06  |
# |    value_loss         | 0.00229   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 797       |
# |    iterations         | 17400     |
# |    time_elapsed       | 109       |
# |    total_timesteps    | 87000     |
# | train/                |           |
# |    entropy_loss       | -0.00209  |
# |    explained_variance | -13.1     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 17399     |
# |    policy_loss        | -1.93e-05 |
# |    value_loss         | 0.00818   |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 797      |
# |    iterations         | 17500    |
# |    time_elapsed       | 109      |
# |    total_timesteps    | 87500    |
# | train/                |          |
# |    entropy_loss       | -0.0028  |
# |    explained_variance | nan      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17499    |
# |    policy_loss        | -0.00018 |
# |    value_loss         | 0.432    |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 797       |
# |    iterations         | 17600     |
# |    time_elapsed       | 110       |
# |    total_timesteps    | 88000     |
# | train/                |           |
# |    entropy_loss       | -0.00112  |
# |    explained_variance | -43.8     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 17599     |
# |    policy_loss        | -1.19e-05 |
# |    value_loss         | 0.00593   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 798       |
# |    iterations         | 17700     |
# |    time_elapsed       | 110       |
# |    total_timesteps    | 88500     |
# | train/                |           |
# |    entropy_loss       | -0.000272 |
# |    explained_variance | -0.613    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 17699     |
# |    policy_loss        | -4.67e-07 |
# |    value_loss         | 0.000603  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 798       |
# |    iterations         | 17800     |
# |    time_elapsed       | 111       |
# |    total_timesteps    | 89000     |
# | train/                |           |
# |    entropy_loss       | -0.0024   |
# |    explained_variance | -35.8     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 17799     |
# |    policy_loss        | -1.41e-05 |
# |    value_loss         | 0.00575   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 798       |
# |    iterations         | 17900     |
# |    time_elapsed       | 112       |
# |    total_timesteps    | 89500     |
# | train/                |           |
# |    entropy_loss       | -0.000444 |
# |    explained_variance | -1.58     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 17899     |
# |    policy_loss        | -9.88e-07 |
# |    value_loss         | 0.000623  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 799      |
# |    iterations         | 18000    |
# |    time_elapsed       | 112      |
# |    total_timesteps    | 90000    |
# | train/                |          |
# |    entropy_loss       | -0.00183 |
# |    explained_variance | -172     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17999    |
# |    policy_loss        | 2.39e-05 |
# |    value_loss         | 0.0207   |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 799       |
# |    iterations         | 18100     |
# |    time_elapsed       | 113       |
# |    total_timesteps    | 90500     |
# | train/                |           |
# |    entropy_loss       | -0.000405 |
# |    explained_variance | -0.731    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18099     |
# |    policy_loss        | 2.11e-07  |
# |    value_loss         | 0.000279  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 800       |
# |    iterations         | 18200     |
# |    time_elapsed       | 113       |
# |    total_timesteps    | 91000     |
# | train/                |           |
# |    entropy_loss       | -0.000332 |
# |    explained_variance | 0.29      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18199     |
# |    policy_loss        | -3.33e-07 |
# |    value_loss         | 0.000169  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 800      |
# |    iterations         | 18300    |
# |    time_elapsed       | 114      |
# |    total_timesteps    | 91500    |
# | train/                |          |
# |    entropy_loss       | -0.00192 |
# |    explained_variance | -129     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18299    |
# |    policy_loss        | 2.42e-05 |
# |    value_loss         | 0.0145   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 801      |
# |    iterations         | 18400    |
# |    time_elapsed       | 114      |
# |    total_timesteps    | 92000    |
# | train/                |          |
# |    entropy_loss       | -0.00039 |
# |    explained_variance | 0.505    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18399    |
# |    policy_loss        | 8.91e-07 |
# |    value_loss         | 0.000745 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 801       |
# |    iterations         | 18500     |
# |    time_elapsed       | 115       |
# |    total_timesteps    | 92500     |
# | train/                |           |
# |    entropy_loss       | -0.000339 |
# |    explained_variance | 0.418     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18499     |
# |    policy_loss        | -6.61e-07 |
# |    value_loss         | 0.000596  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 799      |
# |    iterations         | 18600    |
# |    time_elapsed       | 116      |
# |    total_timesteps    | 93000    |
# | train/                |          |
# |    entropy_loss       | -0.00178 |
# |    explained_variance | 0.715    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18599    |
# |    policy_loss        | -3.4e-05 |
# |    value_loss         | 0.0178   |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 799       |
# |    iterations         | 18700     |
# |    time_elapsed       | 116       |
# |    total_timesteps    | 93500     |
# | train/                |           |
# |    entropy_loss       | -0.000486 |
# |    explained_variance | -5.29     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18699     |
# |    policy_loss        | 4.62e-08  |
# |    value_loss         | 0.000474  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 799       |
# |    iterations         | 18800     |
# |    time_elapsed       | 117       |
# |    total_timesteps    | 94000     |
# | train/                |           |
# |    entropy_loss       | -0.000449 |
# |    explained_variance | 0.252     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18799     |
# |    policy_loss        | -6.49e-07 |
# |    value_loss         | 0.000338  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 798       |
# |    iterations         | 18900     |
# |    time_elapsed       | 118       |
# |    total_timesteps    | 94500     |
# | train/                |           |
# |    entropy_loss       | -0.000761 |
# |    explained_variance | 0.369     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18899     |
# |    policy_loss        | -2.76e-06 |
# |    value_loss         | 0.0017    |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 798      |
# |    iterations         | 19000    |
# |    time_elapsed       | 119      |
# |    total_timesteps    | 95000    |
# | train/                |          |
# |    entropy_loss       | -0.00145 |
# |    explained_variance | -8.82    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18999    |
# |    policy_loss        | 2.1e-05  |
# |    value_loss         | 0.0295   |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 797       |
# |    iterations         | 19100     |
# |    time_elapsed       | 119       |
# |    total_timesteps    | 95500     |
# | train/                |           |
# |    entropy_loss       | -0.00235  |
# |    explained_variance | -30.5     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19099     |
# |    policy_loss        | -2.64e-05 |
# |    value_loss         | 0.0162    |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 797       |
# |    iterations         | 19200     |
# |    time_elapsed       | 120       |
# |    total_timesteps    | 96000     |
# | train/                |           |
# |    entropy_loss       | -0.000359 |
# |    explained_variance | 0.348     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19199     |
# |    policy_loss        | -5.12e-07 |
# |    value_loss         | 0.000312  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 797       |
# |    iterations         | 19300     |
# |    time_elapsed       | 121       |
# |    total_timesteps    | 96500     |
# | train/                |           |
# |    entropy_loss       | -0.000358 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19299     |
# |    policy_loss        | -4.99e-07 |
# |    value_loss         | 0.000326  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 796      |
# |    iterations         | 19400    |
# |    time_elapsed       | 121      |
# |    total_timesteps    | 97000    |
# | train/                |          |
# |    entropy_loss       | -0.00173 |
# |    explained_variance | -36.1    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19399    |
# |    policy_loss        | 8.27e-06 |
# |    value_loss         | 0.00811  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 796       |
# |    iterations         | 19500     |
# |    time_elapsed       | 122       |
# |    total_timesteps    | 97500     |
# | train/                |           |
# |    entropy_loss       | -0.00456  |
# |    explained_variance | -224      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19499     |
# |    policy_loss        | -1.03e-05 |
# |    value_loss         | 0.00906   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 796       |
# |    iterations         | 19600     |
# |    time_elapsed       | 123       |
# |    total_timesteps    | 98000     |
# | train/                |           |
# |    entropy_loss       | -0.000663 |
# |    explained_variance | -15.7     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19599     |
# |    policy_loss        | -4.33e-06 |
# |    value_loss         | 0.00377   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 796       |
# |    iterations         | 19700     |
# |    time_elapsed       | 123       |
# |    total_timesteps    | 98500     |
# | train/                |           |
# |    entropy_loss       | -8.97e-05 |
# |    explained_variance | 0.633     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19699     |
# |    policy_loss        | 5.65e-08  |
# |    value_loss         | 0.00011   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 795       |
# |    iterations         | 19800     |
# |    time_elapsed       | 124       |
# |    total_timesteps    | 99000     |
# | train/                |           |
# |    entropy_loss       | -0.002    |
# |    explained_variance | -100      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19799     |
# |    policy_loss        | -4.63e-05 |
# |    value_loss         | 0.0482    |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 795       |
# |    iterations         | 19900     |
# |    time_elapsed       | 125       |
# |    total_timesteps    | 99500     |
# | train/                |           |
# |    entropy_loss       | -8.85e-05 |
# |    explained_variance | -2.62     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19899     |
# |    policy_loss        | -1.57e-07 |
# |    value_loss         | 0.000989  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 794       |
# |    iterations         | 20000     |
# |    time_elapsed       | 125       |
# |    total_timesteps    | 100000    |
# | train/                |           |
# |    entropy_loss       | -0.00149  |
# |    explained_variance | -56.5     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19999     |
# |    policy_loss        | -1.33e-05 |
# |    value_loss         | 0.00696   |
# -------------------------------------

# %%
A2C_path = os.path.join('Saved Models', 'A2C_1L')
model.save(A2C_path)

# %%
del model

# %%
model = A2C.load(A2C_path)

# %%
evaluate_policy(model, train_env, n_eval_episodes=10)
# Out:
# (np.float64(0.8), np.float64(0.4))

# %%
test_env = gym.make("FrozenLake-v1", render_mode='human')
episodes = 5
for episode in range(episodes):
    obs, _ = test_env.reset()
    done = False
    truncated = False
    score = 0

    while not done and not truncated:
        action, _ = model.predict(obs)
        n_state, reward, done, truncated, info = test_env.step(int(action))
        score += reward
    print(f"Episode: {episode+1} Score: {score}")
test_env.close()
# Out:
# Episode: 1 Score: 0.0
# Episode: 2 Score: 0.0
# Episode: 3 Score: 0.0
# Episode: 4 Score: 0.0
# Episode: 5 Score: 0.0

# %%
net_arch = [dict(pi=[128,128,128,128], vf=[128,128,128,128])]
model = PPO('MlpPolicy', train_env, verbose=1, policy_kwargs={'net_arch':net_arch})
model.learn(total_timesteps=50000)
# Out:
# Using cpu device
# C:\Users\umang\miniconda3\envs\frozen_lake\Lib\site-packages\stable_baselines3\common\policies.py:486: UserWarning: As shared layers in the mlp_extractor are removed since SB3 v1.8.0, you should now pass directly a dictionary and not a list (net_arch=dict(pi=..., vf=...) instead of net_arch=[dict(pi=..., vf=...)])
#   warnings.warn(
# -----------------------------
# | time/              |      |
# |    fps             | 1534 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 973         |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.016897254 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | -3.44       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.018      |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00769    |
# |    value_loss           | 0.0313      |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 861        |
# |    iterations           | 3          |
# |    time_elapsed         | 7          |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.01742152 |
# |    clip_fraction        | 0.202      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.33      |
# |    explained_variance   | -0.0158    |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0303    |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.0151    |
# |    value_loss           | 0.00972    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 807         |
# |    iterations           | 4           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.011425163 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.0801      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0157      |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00927    |
# |    value_loss           | 0.0147      |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 795        |
# |    iterations           | 5          |
# |    time_elapsed         | 12         |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.02314435 |
# |    clip_fraction        | 0.249      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.3       |
# |    explained_variance   | -14.8      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00733   |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.0142    |
# |    value_loss           | 0.000243   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 786         |
# |    iterations           | 6           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.011454215 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.00516     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0194      |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00585    |
# |    value_loss           | 0.0212      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 781         |
# |    iterations           | 7           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.015265696 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.159       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0299     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0106     |
# |    value_loss           | 0.0199      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 776         |
# |    iterations           | 8           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.014939061 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.109       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0289     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00813    |
# |    value_loss           | 0.0247      |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 772        |
# |    iterations           | 9          |
# |    time_elapsed         | 23         |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.01617736 |
# |    clip_fraction        | 0.183      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.18      |
# |    explained_variance   | 0.0638     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00761   |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.00863   |
# |    value_loss           | 0.0184     |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 771          |
# |    iterations           | 10           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0104557015 |
# |    clip_fraction        | 0.157        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.13        |
# |    explained_variance   | 0.154        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00261      |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00689     |
# |    value_loss           | 0.0262       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 769         |
# |    iterations           | 11          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.012507889 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.146       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0274      |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00344    |
# |    value_loss           | 0.0322      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 768         |
# |    iterations           | 12          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.017736048 |
# |    clip_fraction        | 0.228       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.213       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0119      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00975    |
# |    value_loss           | 0.0261      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 756         |
# |    iterations           | 13          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.010167159 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.956      |
# |    explained_variance   | 0.219       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0111      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00785    |
# |    value_loss           | 0.0424      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 756         |
# |    iterations           | 14          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.008501388 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.923      |
# |    explained_variance   | 0.127       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00103    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00473    |
# |    value_loss           | 0.038       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 753         |
# |    iterations           | 15          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.008946905 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.846      |
# |    explained_variance   | 0.231       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0054     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00718    |
# |    value_loss           | 0.0369      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 751         |
# |    iterations           | 16          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.009235555 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.816      |
# |    explained_variance   | 0.169       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0035     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00404    |
# |    value_loss           | 0.0396      |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 751        |
# |    iterations           | 17         |
# |    time_elapsed         | 46         |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.01486474 |
# |    clip_fraction        | 0.134      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.738     |
# |    explained_variance   | 0.115      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0347     |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.00465   |
# |    value_loss           | 0.0479     |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 748         |
# |    iterations           | 18          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.007802138 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.706      |
# |    explained_variance   | 0.166       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00798     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00705    |
# |    value_loss           | 0.0504      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 743         |
# |    iterations           | 19          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.006333192 |
# |    clip_fraction        | 0.0893      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.707      |
# |    explained_variance   | 0.158       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0201      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00293    |
# |    value_loss           | 0.0495      |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 740        |
# |    iterations           | 20         |
# |    time_elapsed         | 55         |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.00969107 |
# |    clip_fraction        | 0.096      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.632     |
# |    explained_variance   | 0.165      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00128   |
# |    n_updates            | 190        |
# |    policy_gradient_loss | -0.00548   |
# |    value_loss           | 0.0503     |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 734         |
# |    iterations           | 21          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.007474102 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.583      |
# |    explained_variance   | 0.203       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00543     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00524    |
# |    value_loss           | 0.0509      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 733         |
# |    iterations           | 22          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.005570308 |
# |    clip_fraction        | 0.0937      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.52       |
# |    explained_variance   | 0.178       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.041       |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00503    |
# |    value_loss           | 0.0602      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 735         |
# |    iterations           | 23          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.008407529 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.489      |
# |    explained_variance   | 0.221       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0424      |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0071     |
# |    value_loss           | 0.062       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 737          |
# |    iterations           | 24           |
# |    time_elapsed         | 66           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0036809668 |
# |    clip_fraction        | 0.0533       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.474       |
# |    explained_variance   | 0.258        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0343       |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00175     |
# |    value_loss           | 0.059        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 738          |
# |    iterations           | 25           |
# |    time_elapsed         | 69           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0029410692 |
# |    clip_fraction        | 0.0551       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.44        |
# |    explained_variance   | 0.213        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.018        |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00267     |
# |    value_loss           | 0.0622       |
# ------------------------------------------

# %%
PPO_path = os.path.join('Saved Models', 'PPO_50K_netArch')
model.save(PPO_path)

# %%
del model

# %%
model = PPO.load(PPO_path)

# %%
evaluate_policy(model, train_env, n_eval_episodes=10)
# Out:
# (np.float64(0.3), np.float64(0.45825756949558394))

# %%
test_env = gym.make("FrozenLake-v1", render_mode='human')
episodes = 5
for episode in range(episodes):
    obs, _ = test_env.reset()
    done = False
    truncated = False
    score = 0

    while not done and not truncated:
        action, _ = model.predict(obs)
        n_state, reward, done, truncated, info = test_env.step(int(action))
        score += reward
    print(f"Episode: {episode+1} Score: {score}")
test_env.close()
# Out:
# Episode: 1 Score: 0.0
# Episode: 2 Score: 0.0
# Episode: 3 Score: 1.0
# Episode: 4 Score: 0.0
# Episode: 5 Score: 0.0
